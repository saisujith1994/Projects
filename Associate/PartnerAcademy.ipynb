# %% [markdown]
# Data ingestion can be done in three types
# 1. Manual Uploading: Uploading from local computer
# 2. Standard Connectors: cloud object storage, Kafka, Message busses etc.
# 3. Managed Connectors: SaaS, DB

# %% [markdown]
# Ingestion is of 2 types:
# 1. Batch & Incremental Batch
# 2. Streaming( Batch & Incremental)

# %%
# %sql
create or replace table sunny_dummy as
select * from read_files('/Volumes/databricks_simulated_gym_data_for_databricks_academy/v01/user-reg/11745.json',format=>'json',header=>true,inferSchema=>true)

# %%
# %sql
select * from sunny_dummy

# %% [markdown]
# CTAS creates rescued column, that stores all the values which deviated from prospose schema

# %%
# %sql

select * from json.`/Volumes/databricks_simulated_gym_data_for_databricks_academy/v01/user-reg/12140.json`

# %%
# %sql
select * from parquet.`/Volumes/e_commerce/v01/raw/users-historical/` limit 10
